# %% [markdown]
# <a href="https://colab.research.google.com/github/Kundurahul07/NLP_LAB/blob/main/Bending_pos_tagger.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# Load English model
nlp = spacy.load("en_core_web_sm")

text = "ChatGPT generates useful code snippets."
doc = nlp(text)

# Print word and POS
for token in doc:
    print(token.text, token.pos_, token.tag_)
# Out:
# ChatGPT NOUN NN
# generates VERB VBZ
# useful ADJ JJ
# code NOUN NN
# snippets NOUN NNS
# . PUNCT .
