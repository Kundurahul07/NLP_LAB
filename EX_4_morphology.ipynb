# %% [markdown]
# <a href="https://colab.research.google.com/github/Kundurahul07/NLP_LAB/blob/main/EX_4_morphology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# Load small English model
nlp = spacy.load("en_core_web_sm")

# Example sentence
text = "The cats are playing happily."

# Process text
doc = nlp(text)

# Print morphology info
for token in doc:
    print(token.text, "→ Lemma:", token.lemma_, "| Morph:", token.morph)
# Out:
# The → Lemma: the | Morph: Definite=Def|PronType=Art
# cats → Lemma: cat | Morph: Number=Plur
# are → Lemma: be | Morph: Mood=Ind|Tense=Pres|VerbForm=Fin
# playing → Lemma: play | Morph: Aspect=Prog|Tense=Pres|VerbForm=Part
# happily → Lemma: happily | Morph:
# . → Lemma: . | Morph: PunctType=Peri
