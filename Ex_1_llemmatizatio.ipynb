# %% [markdown]
# <a href="https://colab.research.google.com/github/Kundurahul07/NLP_LAB/blob/main/Ex_1_llemmatizatio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()

words = ['running', 'feet', 'was', 'better']
lemmas = [lemmatizer.lemmatize(word, pos='v') for word in words]

print(lemmas)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# ['run', 'feet', 'be', 'better']
