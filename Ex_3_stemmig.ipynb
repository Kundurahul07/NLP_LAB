# %% [markdown]
# <a href="https://colab.research.google.com/github/Kundurahul07/NLP_LAB/blob/main/Ex_3_stemmig.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.stem import PorterStemmer

# Create stemmer object
stemmer = PorterStemmer()

# Sample words
words = ["running", "runs", "runner", "easily", "fairly"]

# Apply stemming
for word in words:
    print(word, "→", stemmer.stem(word))
# Out:
# running → run
# runs → run
# runner → runner
# easily → easili
# fairly → fairli
