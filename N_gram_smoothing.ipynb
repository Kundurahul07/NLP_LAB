# %% [markdown]
# <a href="https://colab.research.google.com/github/Kundurahul07/NLP_LAB/blob/main/N_gram_smoothing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import defaultdict

# Sample text
text = "I love learning natural language processing with Python I love Python"
tokens = text.split()

# Vocabulary
vocab = set(tokens)
V = len(vocab)

# Count bigrams
bigram_counts = defaultdict(int)
unigram_counts = defaultdict(int)

for i in range(len(tokens)-1):
    unigram_counts[tokens[i]] += 1
    bigram_counts[(tokens[i], tokens[i+1])] += 1

# Add-one smoothing probability
def bigram_prob(w1, w2):
    return (bigram_counts[(w1, w2)] + 1) / (unigram_counts[w1] + V)

# Example probability
print("P('Python'|'love') =", bigram_prob('love', 'Python'))
print("P('processing'|'love') =", bigram_prob('love', 'processing'))  # unseen bigram
# Out:
# P('Python'|'love') = 0.2
# P('processing'|'love') = 0.1
