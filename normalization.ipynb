# %% [markdown]
# <a href="https://colab.research.google.com/github/Kundurahul07/NLP_LAB/blob/main/normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

text = "ChatGPT generates useful code snippets!"

# Lowercase, remove punctuation, split into words
tokens = re.sub(r'[^\w\s]', '', text.lower()).split()

print(tokens)
# Out:
# ['chatgpt', 'generates', 'useful', 'code', 'snippets']
