# %% [markdown]
# <a href="https://colab.research.google.com/github/Kundurahul07/NLP_LAB/blob/main/uni_gram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sample text
text = "I love learning natural language processing with Python"

# Simple tokenization (split by spaces)
tokens = text.split()

# Unigrams: just the tokens
unigrams = tokens
print("Unigrams:", unigrams)
# Out:
# Unigrams: ['I', 'love', 'learning', 'natural', 'language', 'processing', 'with', 'Python']
